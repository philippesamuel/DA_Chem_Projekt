# %% [markdown]
# # Fragestellung: relative Abweichung zwischen Soll- und Istwert > 5% für einzelne Produkte. Liegt die Ursache in einer "empfindlichen" Chemie oder in der Technik begründet? -> Erzeugung eines Dentrogrammes, bei größerem Einfluss des Faktors "Chemie" sollten die einzelnen Produkte in einem Dentrogramm nah beeinander gruppiert sein.
#
# ## Um unterschiedliche Produkte miteinander vergleichen zu können, müssen Prozessgrößen normiert werden

# %% [markdown]
# ## 1. Einlesen der Daten

# %%
import pandas as pd
import numpy as np
import csv
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# %%
# Daten einlesen
df=pd.read_csv("process_data_df11.csv", header=[0,1], na_values=['nan'],
sep=',',low_memory=False)

# Spalte ohne Information löschen
df2=df.drop(['Unnamed: 0_level_0'],axis=1)


df2.head()
# Out:
# /home/alpha/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py:3946: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   new_axis = axis.drop(labels, errors=errors)
#              ps                                                             \
#              ps    ps_datum ps_beschichtete_rollenlange_m ps_c_losung_wt_%
# 0  cb031d4b18ff  2018-05-13                        4487.0             31.0
# 1  cb031d4b18ff  2018-05-13                        4487.0             31.0
# 2  cb031d4b18ff  2018-05-13                        4487.0             31.0
# 3  cb031d4b18ff  2018-05-13                        4487.0             31.0
# 4  cb031d4b18ff  2018-05-13                        4487.0             31.0
#
#                                                                        \
#   ps_gap_micro_m ps_dicke_as_micro_m ps_dicke_1 ps_dicke_2 ps_dicke_3
# 0          250.0               136.0      136.0      134.0      134.0
# 1          250.0               136.0      136.0      134.0      134.0
# 2          250.0               136.0      136.0      134.0      134.0
# 3          250.0               136.0      136.0      134.0      134.0
# 4          250.0               136.0      136.0      134.0      134.0
#
#               ...             qc                                            \
#   ps_dicke_4  ... qc_flux_l/m2/h qc_a-value_l/m2/h/bar qc_b-value_m/s_10-6
# 0      135.0  ...      40.286235              4.625285            3.678446
# 1      135.0  ...      40.252401              4.621401            3.165247
# 2      135.0  ...      39.718186              4.560067            3.170593
# 3      135.0  ...      39.441426              4.528292            2.855092
# 4      135.0  ...      39.731817              4.561632            2.810373
#
#                                                     Sollwerte  \
#   qc_flux_m3/m2/day sum_of_scrap roll_position soll_salzr_abs
# 0          0.966870          0.0     58.181818           99.5
# 1          0.966058          0.0    116.363636           99.5
# 2          0.953236          0.0    174.545455           99.5
# 3          0.946594          0.0    232.727273           99.5
# 4          0.953564          0.0    290.909091           99.5
#
#
#   soll_permeatd_abs soll_salzr_rel soll_permeatd_rel
# 0              36.2       0.045087          1.707208
# 1              36.2       0.030558          1.621790
# 2              36.2       0.023437          0.273103
# 3              36.2       0.067889          0.425610
# 4              36.2       0.077781          0.307515
#
# [5 rows x 347 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118670 entries, 0 to 118669
# Columns: 347 entries, (ps, ps) to (Sollwerte, soll_permeatd_rel)
# dtypes: bool(7), float64(300), int64(4), object(36)
# memory usage: 308.6+ MB

# %%
df3=df2.copy()

# %%
df3=df3.droplevel(level=0,axis=1)

# %%
# Annahme: jedes Produkt besitzt einge Vorgaben für Prozessgrößen
# -> Normierung muss für jedes Produkt erfolgen
#  -> Entscheidend für die Fehleranfälligkeit ist Streuung der Prozessparameter um die Norm

df3=df3.set_index('p_product_full_name') #merken, um jedes produzierte Produkt zu identifizieren

# %% [markdown]
# ## 2. Vorbereiten des Datensatzes für die Normierung

# %% [markdown]
# ### 2.1 Typfilterung

# %%
# alle Prozessgrößen müssen Zahlen (int, float) sein
# Entfernen von allem, was keine Zahl ist

df3=df3.select_dtypes(include=['float64','int'])

# %% [markdown]
# ### 2.2 Entfernen von Spalten, die zwar typ: int oder typ: float sind, deren Normierung jedoch physikalisch nicht sinnvoll ist

# %%
df3=df3.drop(columns=['roll_position']) #Position, an der qc-Messung der Rolle stattfand
df3=df3.drop(columns=['qc_p_position','nr'])
#df3=df3.drop(columns=['nr'])

# %%
df3=df3.reset_index()

# %%
df3.head()
# Out:
#   p_product_full_name  ps_beschichtete_rollenlange_m  ps_c_losung_wt_%  \
# 0        b3ccc5e5f9b5                         4487.0              31.0
# 1        b3ccc5e5f9b5                         4487.0              31.0
# 2        b3ccc5e5f9b5                         4487.0              31.0
# 3        b3ccc5e5f9b5                         4487.0              31.0
# 4        b3ccc5e5f9b5                         4487.0              31.0
#
#    ps_gap_micro_m  ps_dicke_as_micro_m  ps_dicke_1  ps_dicke_2  ps_dicke_3  \
# 0           250.0                136.0       136.0       134.0       134.0
# 1           250.0                136.0       136.0       134.0       134.0
# 2           250.0                136.0       136.0       134.0       134.0
# 3           250.0                136.0       136.0       134.0       134.0
# 4           250.0                136.0       136.0       134.0       134.0
#
#    ps_dicke_4  ps_dicke_bs  ...  p_effective_pressure_bar  qc_flux_l/m2/h  \
# 0       135.0        134.0  ...                      8.71       40.286235
# 1       135.0        134.0  ...                      8.71       40.252401
# 2       135.0        134.0  ...                      8.71       39.718186
# 3       135.0        134.0  ...                      8.71       39.441426
# 4       135.0        134.0  ...                      8.71       39.731817
#
#    qc_a-value_l/m2/h/bar  qc_b-value_m/s_10-6  qc_flux_m3/m2/day  \
# 0               4.625285             3.678446           0.966870
# 1               4.621401             3.165247           0.966058
# 2               4.560067             3.170593           0.953236
# 3               4.528292             2.855092           0.946594
# 4               4.561632             2.810373           0.953564
#
#    sum_of_scrap  soll_salzr_abs  soll_permeatd_abs  soll_salzr_rel  \
# 0           0.0            99.5               36.2        0.045087
# 1           0.0            99.5               36.2        0.030558
# 2           0.0            99.5               36.2        0.023437
# 3           0.0            99.5               36.2        0.067889
# 4           0.0            99.5               36.2        0.077781
#
#    soll_permeatd_rel
# 0           1.707208
# 1           1.621790
# 2           0.273103
# 3           0.425610
# 4           0.307515
#
# [5 rows x 302 columns]

# %%
#df3.groubby(['p_product_full_name'])

# %%
#is_p1=df3['p_product_full_name']=='0cc0ba87b12f'

# %%
#df_p1=df3[is_p1]

# %%
#df_p1

# %% [markdown]
# ## 3. Normierung

# %%
# Liste mit allem Produktnamen 
# -> dient als Filter für Iteration
produktnamen=['a79cf6a73839','c807697b3c7e','f22a7fef71c5','c13b2f69d3c1','3e94b7067349','3394d82edc97','df9e75b29918','316c8d1ffca1','5661014763c8','73928f2577b5','22227b31350f','df1d09e643af','e2b1e6e1d5f5','54b98d0fe2eb','ff16223eb2bf','0cc0ba87b12f','a640f68db89c','b3ccc5e5f9b5','2256f65c362b','33d21930e431','3a0c28c7fc8c','630448a85ca3']

# %%
# Erzeugen eines leeren DataFrames, in welches die normierten Werte eingetragen werden
df_norm=pd.DataFrame()

for i in range(len(produktnamen)):
    
    # 1.Filtern nach Produktname und Erzeugen eines DataFrames, in welchem die Normierung erfolgt
    # !! Index ändert sich !!
    to_norm=df3['p_product_full_name']==produktnamen[i]
    df_n=df3[to_norm]
    
    # 2. Merken von Größen, welche nicht normieret werden können (product_name) oder es bereits sind (relative Werte)
    # !! Gleicher Index für diese Größen für df_n und df_n2 
    #  -> können später problemlos wieder angefügt werden
    df_n2=df_n.copy()
    df_n=df_n.drop(columns=['p_product_full_name','soll_salzr_rel', 'soll_permeatd_rel'])
    
    # Wahl der Normierungsmethode
    df_n=(df_n-df_n.min())/(df_n.max()-df_n.min())
    #df_n=(df_n-df_n.mean())/df_n.std()
    
    # Anfügen der Größen, welche nicht normiert werden sollen
    # sowie sukzessives Einfügen der normierten DataFrames in das leere DataFrame df_norm
    df_n['p_product_full_name']=df_n2['p_product_full_name']
    df_n['soll_salzr_rel']=df_n2['soll_salzr_rel']
    df_n['soll_permeatd_rel']=df_n2['soll_permeatd_rel']
    df_n.set_index('p_product_full_name')
    df_norm=df_norm.append(df_n, ignore_index=True)

# %%
df_norm
# Out:
#         ps_beschichtete_rollenlange_m  ps_c_losung_wt_%  ps_gap_micro_m  \
# 0                            1.000000               NaN             NaN
# 1                            1.000000               NaN             NaN
# 2                            1.000000               NaN             NaN
# 3                            1.000000               NaN             NaN
# 4                            1.000000               NaN             NaN
# ...                               ...               ...             ...
# 118649                       0.988792               NaN             NaN
# 118650                       0.988792               NaN             NaN
# 118651                       0.988792               NaN             NaN
# 118652                       0.988792               NaN             NaN
# 118653                       0.988792               NaN             NaN
#
#         ps_dicke_as_micro_m  ps_dicke_1  ps_dicke_2  ps_dicke_3  ps_dicke_4  \
# 0                  1.000000    1.000000       1.000       0.000         NaN
# 1                  1.000000    1.000000       1.000       0.000         NaN
# 2                  1.000000    1.000000       1.000       0.000         NaN
# 3                  1.000000    1.000000       1.000       0.000         NaN
# 4                  1.000000    1.000000       1.000       0.000         NaN
# ...                     ...         ...         ...         ...         ...
# 118649             0.444444    0.428571       0.375       0.625    0.444444
# 118650             0.444444    0.428571       0.375       0.625    0.444444
# 118651             0.444444    0.428571       0.375       0.625    0.444444
# 118652             0.444444    0.428571       0.375       0.625    0.444444
# 118653             0.444444    0.428571       0.375       0.625    0.444444
#
#         ps_dicke_bs  ps_raum_temperatur_start_c  ...  qc_flux_l/m2/h  \
# 0             1.000                         NaN  ...        0.506699
# 1             1.000                         NaN  ...        0.519579
# 2             1.000                         NaN  ...        0.568144
# 3             1.000                         NaN  ...        0.548385
# 4             1.000                         NaN  ...        0.563722
# ...             ...                         ...  ...             ...
# 118649        0.375                         0.5  ...        0.351294
# 118650        0.375                         0.5  ...        0.350004
# 118651        0.375                         0.5  ...        0.351034
# 118652        0.375                         0.5  ...        0.368918
# 118653        0.375                         0.5  ...        0.361278
#
#         qc_a-value_l/m2/h/bar  qc_b-value_m/s_10-6  qc_flux_m3/m2/day  \
# 0                    0.506699             0.143686           0.506699
# 1                    0.519579             0.145616           0.519579
# 2                    0.568144             0.191241           0.568144
# 3                    0.548385             0.146440           0.548385
# 4                    0.563722             0.158999           0.563722
# ...                       ...                  ...                ...
# 118649               0.351294             0.001043           0.351294
# 118650               0.350004             0.001058           0.350004
# 118651               0.351034             0.001075           0.351034
# 118652               0.368918             0.001098           0.368918
# 118653               0.361278             0.001168           0.361278
#
#         sum_of_scrap  soll_salzr_abs  soll_permeatd_abs  p_product_full_name  \
# 0                NaN             NaN                NaN         a79cf6a73839
# 1                NaN             NaN                NaN         a79cf6a73839
# 2                NaN             NaN                NaN         a79cf6a73839
# 3                NaN             NaN                NaN         a79cf6a73839
# 4                NaN             NaN                NaN         a79cf6a73839
# ...              ...             ...                ...                  ...
# 118649           1.0             NaN                NaN         630448a85ca3
# 118650           1.0             NaN                NaN         630448a85ca3
# 118651           1.0             NaN                NaN         630448a85ca3
# 118652           1.0             NaN                NaN         630448a85ca3
# 118653           1.0             NaN                NaN         630448a85ca3
#
#         soll_salzr_rel  soll_permeatd_rel
# 0             0.106052           0.347577
# 1             0.102480           2.898316
# 2             0.163156          12.516333
# 3             0.088234           8.603211
# 4             0.104414          11.640462
# ...                ...                ...
# 118649        0.386905          20.371214
# 118650        0.402724          19.929047
# 118651        0.414076          20.282138
# 118652        0.388926          26.410032
# 118653        0.464903          23.792012
#
# [118654 rows x 302 columns]

# %%
df_norm2=df_norm.copy()

# %%
df_norm2=df_norm2.set_index('p_product_full_name')

# %%
df_norm2.head()
# Out:
#                      ps_beschichtete_rollenlange_m  ps_c_losung_wt_%  \
# p_product_full_name
# a79cf6a73839                                   1.0               NaN
# a79cf6a73839                                   1.0               NaN
# a79cf6a73839                                   1.0               NaN
# a79cf6a73839                                   1.0               NaN
# a79cf6a73839                                   1.0               NaN
#
#                      ps_gap_micro_m  ps_dicke_as_micro_m  ps_dicke_1  \
# p_product_full_name
# a79cf6a73839                    NaN                  1.0         1.0
# a79cf6a73839                    NaN                  1.0         1.0
# a79cf6a73839                    NaN                  1.0         1.0
# a79cf6a73839                    NaN                  1.0         1.0
# a79cf6a73839                    NaN                  1.0         1.0
#
#                      ps_dicke_2  ps_dicke_3  ps_dicke_4  ps_dicke_bs  \
# p_product_full_name
# a79cf6a73839                1.0         0.0         NaN          1.0
# a79cf6a73839                1.0         0.0         NaN          1.0
# a79cf6a73839                1.0         0.0         NaN          1.0
# a79cf6a73839                1.0         0.0         NaN          1.0
# a79cf6a73839                1.0         0.0         NaN          1.0
#
#                      ps_raum_temperatur_start_c  ...  \
# p_product_full_name                              ...
# a79cf6a73839                                NaN  ...
# a79cf6a73839                                NaN  ...
# a79cf6a73839                                NaN  ...
# a79cf6a73839                                NaN  ...
# a79cf6a73839                                NaN  ...
#
#                      p_effective_pressure_bar  qc_flux_l/m2/h  \
# p_product_full_name
# a79cf6a73839                              NaN        0.506699
# a79cf6a73839                              NaN        0.519579
# a79cf6a73839                              NaN        0.568144
# a79cf6a73839                              NaN        0.548385
# a79cf6a73839                              NaN        0.563722
#
#                      qc_a-value_l/m2/h/bar  qc_b-value_m/s_10-6  \
# p_product_full_name
# a79cf6a73839                      0.506699             0.143686
# a79cf6a73839                      0.519579             0.145616
# a79cf6a73839                      0.568144             0.191241
# a79cf6a73839                      0.548385             0.146440
# a79cf6a73839                      0.563722             0.158999
#
#                      qc_flux_m3/m2/day  sum_of_scrap  soll_salzr_abs  \
# p_product_full_name
# a79cf6a73839                  0.506699           NaN             NaN
# a79cf6a73839                  0.519579           NaN             NaN
# a79cf6a73839                  0.568144           NaN             NaN
# a79cf6a73839                  0.548385           NaN             NaN
# a79cf6a73839                  0.563722           NaN             NaN
#
#                      soll_permeatd_abs  soll_salzr_rel  soll_permeatd_rel
# p_product_full_name
# a79cf6a73839                       NaN        0.106052           0.347577
# a79cf6a73839                       NaN        0.102480           2.898316
# a79cf6a73839                       NaN        0.163156          12.516333
# a79cf6a73839                       NaN        0.088234           8.603211
# a79cf6a73839                       NaN        0.104414          11.640462
#
# [5 rows x 301 columns]

# %%
# Filtert man das DataFrame nach den verschiedenen Produktname, treten Konstanten Spalten auf (z.B. ps_c_losung_wt_%)
# -> Annahme: Es handelt sich dabei um spezifische Vorgaben für die Produktion eines jeweiligen Produktes (weil sie eben nicht über im kompletten DataFrame konstant sind)
# -> Erzeugen NaN-Einträge, da beim Normieren durch 0 geteilt wird (df_n.max()=df_n.min())
#  -> Müssen Entfernt werden, da uns Schwankungen einzelner Prozessgrößen innerhalb eines Produktes interessieren

df_norm3=df_norm2.dropna(axis='columns', how='any')

# %%
df_norm3.head()
# Out:
#                      ps_beschichtete_rollenlange_m  ps_dicke_1  ps_dicke_2  \
# p_product_full_name
# a79cf6a73839                                   1.0         1.0         1.0
# a79cf6a73839                                   1.0         1.0         1.0
# a79cf6a73839                                   1.0         1.0         1.0
# a79cf6a73839                                   1.0         1.0         1.0
# a79cf6a73839                                   1.0         1.0         1.0
#
#                      ps_dicke_3  ps_dicke_bs  ps_bad_temperatur_0m_c  \
# p_product_full_name
# a79cf6a73839                0.0          1.0                     0.0
# a79cf6a73839                0.0          1.0                     0.0
# a79cf6a73839                0.0          1.0                     0.0
# a79cf6a73839                0.0          1.0                     0.0
# a79cf6a73839                0.0          1.0                     0.0
#
#                      ps_bad_temperatur_500m_c  ps_bad_temperatur_1000m_c  \
# p_product_full_name
# a79cf6a73839                              0.0                        0.0
# a79cf6a73839                              0.0                        0.0
# a79cf6a73839                              0.0                        0.0
# a79cf6a73839                              0.0                        0.0
# a79cf6a73839                              0.0                        0.0
#
#                      ps_bad_temperatur_1500m_c  ps_bad_temperatur_2000m_c  \
# p_product_full_name
# a79cf6a73839                               1.0                        1.0
# a79cf6a73839                               1.0                        1.0
# a79cf6a73839                               1.0                        1.0
# a79cf6a73839                               1.0                        1.0
# a79cf6a73839                               1.0                        1.0
#
#                      ...  total_yield_%  qc_lasttest  qc_salzrckhalt  \
# p_product_full_name  ...
# a79cf6a73839         ...            1.0         0.25        0.999241
# a79cf6a73839         ...            1.0         0.25        0.999277
# a79cf6a73839         ...            1.0         0.25        0.998670
# a79cf6a73839         ...            1.0         0.25        0.999420
# a79cf6a73839         ...            1.0         0.25        0.999258
#
#                      qc_durchfluss  qc_flux_l/m2/h  qc_a-value_l/m2/h/bar  \
# p_product_full_name
# a79cf6a73839              0.506699        0.506699               0.506699
# a79cf6a73839              0.519579        0.519579               0.519579
# a79cf6a73839              0.568144        0.568144               0.568144
# a79cf6a73839              0.548385        0.548385               0.548385
# a79cf6a73839              0.563722        0.563722               0.563722
#
#                      qc_b-value_m/s_10-6  qc_flux_m3/m2/day  soll_salzr_rel  \
# p_product_full_name
# a79cf6a73839                    0.143686           0.506699        0.106052
# a79cf6a73839                    0.145616           0.519579        0.102480
# a79cf6a73839                    0.191241           0.568144        0.163156
# a79cf6a73839                    0.146440           0.548385        0.088234
# a79cf6a73839                    0.158999           0.563722        0.104414
#
#                      soll_permeatd_rel
# p_product_full_name
# a79cf6a73839                  0.347577
# a79cf6a73839                  2.898316
# a79cf6a73839                 12.516333
# a79cf6a73839                  8.603211
# a79cf6a73839                 11.640462
#
# [5 rows x 118 columns]

# %%
# 116 Spalten von ursprünglich 347 noch übrig
df_norm3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118654 entries, a79cf6a73839 to 630448a85ca3
# Columns: 118 entries, ps_beschichtete_rollenlange_m to soll_permeatd_rel
# dtypes: float64(118)
# memory usage: 107.7+ MB

# %% [markdown]
# ## 4. Auswählen der Daten und Erzeugung eines Dentrogrammes

# %% [markdown]
# ### 4.1 Salzrückhalt

# %% [markdown]
# #### 4.1.1 Filterkriterium

# %%
df_norm4=df_norm3[(df_norm3['soll_salzr_rel']>10) & (df_norm3['soll_salzr_rel']<100) ]

# %%
# Jeder 1000 Eintrag hat eine Abweichung größer als 5%
df_norm4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72 entries, 316c8d1ffca1 to 630448a85ca3
# Columns: 118 entries, ps_beschichtete_rollenlange_m to soll_permeatd_rel
# dtypes: float64(118)
# memory usage: 66.9+ KB

# %%
df_norm4.tail()
# Out:
#                      ps_beschichtete_rollenlange_m  ps_dicke_1  ps_dicke_2  \
# p_product_full_name
# 630448a85ca3                              0.988792    0.571429       0.625
# 630448a85ca3                              0.983811    0.571429       0.750
# 630448a85ca3                              0.843088    0.428571       0.500
# 630448a85ca3                              0.845579    0.428571       0.500
# 630448a85ca3                              0.940224    0.714286       0.750
#
#                      ps_dicke_3  ps_dicke_bs  ps_bad_temperatur_0m_c  \
# p_product_full_name
# 630448a85ca3              0.750        0.625                0.115702
# 630448a85ca3              0.875        1.000                0.107438
# 630448a85ca3              0.625        0.625                0.132231
# 630448a85ca3              0.500        0.500                0.148760
# 630448a85ca3              0.750        0.875                0.099174
#
#                      ps_bad_temperatur_500m_c  ps_bad_temperatur_1000m_c  \
# p_product_full_name
# 630448a85ca3                         0.093750                   0.157895
# 630448a85ca3                         0.083333                   0.144737
# 630448a85ca3                         0.114583                   0.144737
# 630448a85ca3                         0.125000                   0.184211
# 630448a85ca3                         0.052083                   0.105263
#
#                      ps_bad_temperatur_1500m_c  ps_bad_temperatur_2000m_c  \
# p_product_full_name
# 630448a85ca3                          0.200000                   0.181818
# 630448a85ca3                          0.183333                   0.159091
# 630448a85ca3                          0.166667                   0.136364
# 630448a85ca3                          0.216667                   0.159091
# 630448a85ca3                          0.150000                   0.136364
#
#                      ...  total_yield_%  qc_lasttest  qc_salzrckhalt  \
# p_product_full_name  ...
# 630448a85ca3         ...       0.988889     0.666667        0.241982
# 630448a85ca3         ...       0.766667     0.333333        0.626512
# 630448a85ca3         ...       0.744444     0.666667        0.335836
# 630448a85ca3         ...       0.966667     0.666667        0.884449
# 630448a85ca3         ...       0.833333     0.666667        0.634598
#
#                      qc_durchfluss  qc_flux_l/m2/h  qc_a-value_l/m2/h/bar  \
# p_product_full_name
# 630448a85ca3              0.956561        0.956561               0.956561
# 630448a85ca3              0.563073        0.563073               0.563073
# 630448a85ca3              0.754659        0.754659               0.754659
# 630448a85ca3              0.394116        0.394116               0.394116
# 630448a85ca3              0.496583        0.496583               0.496583
#
#                      qc_b-value_m/s_10-6  qc_flux_m3/m2/day  soll_salzr_rel  \
# p_product_full_name
# 630448a85ca3                    1.000000           0.956561       75.739338
# 630448a85ca3                    0.112392           0.563073       37.187137
# 630448a85ca3                    0.498295           0.754659       66.329747
# 630448a85ca3                    0.017490           0.394116       11.326925
# 630448a85ca3                    0.095752           0.496583       36.376511
#
#                      soll_permeatd_rel
# p_product_full_name
# 630448a85ca3                227.766230
# 630448a85ca3                 92.937199
# 630448a85ca3                158.584149
# 630448a85ca3                 35.044016
# 630448a85ca3                 70.154356
#
# [5 rows x 118 columns]

# %% [markdown]
# #### 4.1.2 Erzeugung der Labels

# %%
df_norm5=df_norm4.copy()

# %%
df_norm5=df_norm5.sort_index()
df_norm5.head()
# Out:
#                      ps_beschichtete_rollenlange_m  ps_dicke_1  ps_dicke_2  \
# p_product_full_name
# 0cc0ba87b12f                              0.012576    0.333333         0.2
# 0cc0ba87b12f                              0.012576    0.333333         0.2
# 22227b31350f                              0.084871    0.470588         0.4
# 22227b31350f                              0.084756    0.294118         0.2
# 22227b31350f                              0.085374    0.235294         0.2
#
#                      ps_dicke_3  ps_dicke_bs  ps_bad_temperatur_0m_c  \
# p_product_full_name
# 0cc0ba87b12f             0.2500     0.285714                1.000000
# 0cc0ba87b12f             0.2500     0.285714                1.000000
# 22227b31350f             0.4375     0.421053                0.767442
# 22227b31350f             0.1875     0.263158                0.627907
# 22227b31350f             0.3125     0.368421                0.186047
#
#                      ps_bad_temperatur_500m_c  ps_bad_temperatur_1000m_c  \
# p_product_full_name
# 0cc0ba87b12f                         1.000000                   1.000000
# 0cc0ba87b12f                         1.000000                   1.000000
# 22227b31350f                         0.921397                   0.931624
# 22227b31350f                         0.908297                   0.905983
# 22227b31350f                         0.925764                   0.910256
#
#                      ps_bad_temperatur_1500m_c  ps_bad_temperatur_2000m_c  \
# p_product_full_name
# 0cc0ba87b12f                          1.000000                   1.000000
# 0cc0ba87b12f                          1.000000                   1.000000
# 22227b31350f                          0.933610                   0.946721
# 22227b31350f                          0.892116                   0.889344
# 22227b31350f                          0.904564                   0.901639
#
#                      ...  total_yield_%  qc_lasttest  qc_salzrckhalt  \
# p_product_full_name  ...
# 0cc0ba87b12f         ...       0.455635          0.5        0.762383
# 0cc0ba87b12f         ...       0.455635          0.5        0.653932
# 22227b31350f         ...       0.897959          0.4        0.866718
# 22227b31350f         ...       0.826531          0.4        0.875504
# 22227b31350f         ...       0.112245          0.4        0.892636
#
#                      qc_durchfluss  qc_flux_l/m2/h  qc_a-value_l/m2/h/bar  \
# p_product_full_name
# 0cc0ba87b12f              0.496312        0.496312               0.496312
# 0cc0ba87b12f              0.648182        0.648182               0.648182
# 22227b31350f              0.581556        0.581556               0.581556
# 22227b31350f              0.622749        0.622749               0.622749
# 22227b31350f              0.577466        0.577466               0.577466
#
#                      qc_b-value_m/s_10-6  qc_flux_m3/m2/day  soll_salzr_rel  \
# p_product_full_name
# 0cc0ba87b12f                    0.450954           0.496312       23.378572
# 0cc0ba87b12f                    1.000000           0.648182       34.278185
# 22227b31350f                    0.309397           0.581556       12.892626
# 22227b31350f                    0.306367           0.622749       12.009655
# 22227b31350f                    0.240294           0.577466       10.287840
#
#                      soll_permeatd_rel
# p_product_full_name
# 0cc0ba87b12f                 43.715483
# 0cc0ba87b12f                 87.692217
# 22227b31350f                 35.749183
# 22227b31350f                 45.364499
# 22227b31350f                 34.794443
#
# [5 rows x 118 columns]

# %%
df_norm5=df_norm5.reset_index()

# %%
df_norm5.head()
# Out:
#   p_product_full_name  ps_beschichtete_rollenlange_m  ps_dicke_1  ps_dicke_2  \
# 0        0cc0ba87b12f                       0.012576    0.333333         0.2
# 1        0cc0ba87b12f                       0.012576    0.333333         0.2
# 2        22227b31350f                       0.084871    0.470588         0.4
# 3        22227b31350f                       0.084756    0.294118         0.2
# 4        22227b31350f                       0.085374    0.235294         0.2
#
#    ps_dicke_3  ps_dicke_bs  ps_bad_temperatur_0m_c  ps_bad_temperatur_500m_c  \
# 0      0.2500     0.285714                1.000000                  1.000000
# 1      0.2500     0.285714                1.000000                  1.000000
# 2      0.4375     0.421053                0.767442                  0.921397
# 3      0.1875     0.263158                0.627907                  0.908297
# 4      0.3125     0.368421                0.186047                  0.925764
#
#    ps_bad_temperatur_1000m_c  ps_bad_temperatur_1500m_c  ...  total_yield_%  \
# 0                   1.000000                   1.000000  ...       0.455635
# 1                   1.000000                   1.000000  ...       0.455635
# 2                   0.931624                   0.933610  ...       0.897959
# 3                   0.905983                   0.892116  ...       0.826531
# 4                   0.910256                   0.904564  ...       0.112245
#
#    qc_lasttest  qc_salzrckhalt  qc_durchfluss  qc_flux_l/m2/h  \
# 0          0.5        0.762383       0.496312        0.496312
# 1          0.5        0.653932       0.648182        0.648182
# 2          0.4        0.866718       0.581556        0.581556
# 3          0.4        0.875504       0.622749        0.622749
# 4          0.4        0.892636       0.577466        0.577466
#
#    qc_a-value_l/m2/h/bar  qc_b-value_m/s_10-6  qc_flux_m3/m2/day  \
# 0               0.496312             0.450954           0.496312
# 1               0.648182             1.000000           0.648182
# 2               0.581556             0.309397           0.581556
# 3               0.622749             0.306367           0.622749
# 4               0.577466             0.240294           0.577466
#
#    soll_salzr_rel  soll_permeatd_rel
# 0       23.378572          43.715483
# 1       34.278185          87.692217
# 2       12.892626          35.749183
# 3       12.009655          45.364499
# 4       10.287840          34.794443
#
# [5 rows x 119 columns]

# %%
prod_appearance=df_norm5['p_product_full_name'].tolist()
prod_appearance_if_cond=prod_appearance.copy() # Vergleichsbedingung; ursprüngliche List wird überschrieben werden

# %%
prod_appearance
# Out:
# ['0cc0ba87b12f',
#  '0cc0ba87b12f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '22227b31350f',
#  '2256f65c362b',
#  '2256f65c362b',
#  '2256f65c362b',
#  '316c8d1ffca1',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '3a0c28c7fc8c',
#  '5661014763c8',
#  '5661014763c8',
#  '5661014763c8',
#  '5661014763c8',
#  '5661014763c8',
#  '630448a85ca3',
#  '630448a85ca3',
#  '630448a85ca3',
#  '630448a85ca3',
#  '630448a85ca3',
#  '630448a85ca3',
#  '630448a85ca3',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  '73928f2577b5',
#  'a640f68db89c',
#  'b3ccc5e5f9b5',
#  'b3ccc5e5f9b5',
#  'df1d09e643af',
#  'df1d09e643af',
#  'e2b1e6e1d5f5',
#  'e2b1e6e1d5f5',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf',
#  'ff16223eb2bf']

# %%
# Durchnummerieren der einzelnen Produkte
for i in range(len(prod_appearance)):
    if i==0:
        j=1
        prod_appearance[i]=prod_appearance[i][:4]+"_"+str(j)
    elif prod_appearance_if_cond[i]==prod_appearance_if_cond[i-1]:
        j=j+1
        prod_appearance[i]=prod_appearance[i][:4]+"_"+str(j)
    else:
        j=1
        prod_appearance[i]=prod_appearance[i][:4]+"_"+str(j)

# %%
#prod_appearance[1][:4]

# %%
df_norm6=df_norm5.drop(columns=['p_product_full_name','soll_salzr_rel', 'soll_permeatd_rel'])

# %%
df_norm6.head()

# %%
df_norm_dendro=df_norm6.to_numpy()

# %%
mergings=linkage(df_norm_dendro, method='complete')

# %%
plt.figure(figsize=(50,30))
dendrogram(mergings,labels=prod_appearance, leaf_rotation=90, leaf_font_size=26,)
plt.show()
